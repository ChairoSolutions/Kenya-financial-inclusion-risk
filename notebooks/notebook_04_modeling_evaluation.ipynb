# %% [markdown]
# ## Why This Is a Classification Problem
# This project is a classification problem because the model is predicting a category or class rather than a continuous numerical value.The target variable is:
# 1 = Financially Excluded
# 0 = Financially Included.
# Since the model must decide whether an individual belongs to one of these two categories, the task is specifically a binary classification problem.
# The goal is not to predict an amount such as income or savings, but to classify individuals into exclusion-risk groups based on demographic, geographic, and financial characteristics.

# %% [markdown]
# ### Logistic Regression
# Logistic Regression is a supervised machine learning algorithm commonly used for binary classification problems. It predicts the probability that an observation belongs to a particular class.
# In this project, Logistic Regression can estimate the probability that a Kenyan adult is financially excluded.
# #### Why Logistic Regression is Important
# * Easy to interpret
# * Fast to train
#
# Works well as a baseline model
# Provides probability outputs
# Commonly used in financial risk analysis
# #### Why It Fits This Project
# The project needs an interpretable model that can show how factors such as education, employment, rural location, or mobile money usage affect financial exclusion risk.

# %% [markdown]
# ## Random Forest
# Random Forest is an ensemble learning algorithm that combines many decision trees to improve prediction accuracy and reduce overfitting.
# Instead of relying on one tree, the model creates multiple trees and combines their predictions.
# #### Why Random Forest is Useful
# * Handles complex relationships well
# * Works with categorical and numerical data
# * Reduces overfitting compared to a single decision tree
# * Captures nonlinear patterns
# * Provides feature importance scores
# #### Why It Fits This Project
# Financial exclusion is influenced by many interacting socioeconomic factors. Random Forest can capture hidden relationships between variables such as county, education, employment status, and digital finance access.

# %% [markdown]
# ## Gradient Boosting
# Gradient Boosting is another ensemble machine learning method that builds models sequentially. Each new model attempts to correct the errors made by the previous model.
# The algorithm gradually improves prediction performance by focusing on difficult cases.
# #### Why Gradient Boosting is Useful
# * Often achieves high predictive accuracy
# * Handles complex nonlinear patterns
# * Works well on structured/tabular data
# * Can identify subtle risk patterns
# #### Why It Fits This Project
# - Captures Complex Relationships
# Financial exclusion is affected by multiple interacting socioeconomic factors. Gradient Boosting can model nonlinear relationships and hidden interactions better than traditional linear models.
# - Higher Predictive Performance
# Gradient Boosting often performs better than simpler algorithms on structured/tabular datasets such as survey data.
# - Handles Mixed Features Well
# The project includes:Categorical variables,Numerical variables, Binary indicators
# Gradient Boosting handles these effectively after preprocessing.
# - Focuses on Difficult Cases
# The algorithm pays more attention to observations that previous models predicted incorrectly. This is useful when identifying vulnerable or difficult-to-detect financially excluded individuals.
# - Works Well with Imbalanced Data
# If financially excluded individuals form a smaller portion of the dataset, Gradient Boosting can still perform effectively when combined with proper evaluation metrics and imbalance handling techniques.

# %% [markdown]
# ## Why Recall Matters
# Recall measures how well the model identifies actual positive cases.
# In this project, the positive class is:
# Financially Excluded Individuals
# #### Why Recall Is Important
# The main goal of the project is to identify people who are truly financially excluded.
# A low recall score means the model is failing to identify many excluded individuals. These missed cases are called false negatives.
# In real-world use
# Banks may fail to reach underserved populations
# Policymakers may underestimate exclusion levels
# Financial inclusion programs may miss vulnerable groups
# Because of this, recall is especially important for ensuring vulnerable individuals are correctly identified.

# %% [markdown]
# ## Planned Evaluation Metrics
# The project will evaluate models using:
# * Accuracy → Overall correctness of predictions
# * Precision → How many predicted excluded individuals are truly excluded
# * Recall → How many truly excluded individuals are correctly identified
# * F1-Score → Balance between precision and recall
# * ROC-AUC → Ability to separate excluded vs included individuals
# * Confusion Matrix → Breakdown of prediction performance

# %% [markdown]
# ## Baseline Model Choice
# The baseline model for this project will be Logistic Regression.
# #### Why Logistic Regression Was Chosen
# * Simple and interpretable
# * Fast to implement
# * Common baseline for classification tasks
# * Produces probability scores
# * Easy to compare against more advanced models
#
# Using Logistic Regression as the baseline allows later models such as Random Forest and Gradient Boosting to be evaluated against a simple, understandable starting point.

# %% [markdown]
# ## Planned Modeling Workflow
# 1. __Data Loading__
# * Load FinAccess 2021 dataset
# * Inspect structure and variables
# * Review data dictionary and coded responses
# 2. __Data Cleaning__
# * Handle missing values
# * Remove duplicates
# * Decode categorical variables
# * Fix inconsistent labels
# 3. __Target Variable Creation__
# Create:
# * 1 = Financially Excluded
# * 0 = Financially Included
# Using financial service access indicators.
# 4. __Feature Selection__
#
# Select relevant variables such as:
# * County
# * Gender
# * Age
# * Education
# * Employment
# * Rural/urban location
# * Mobile money usage
# * Bank account usage
# * SACCO usage
# * Insurance access
# 5. __Feature Engineering__
#
# Possible engineered features:
# * Youth indicator
# * Rural youth indicator
# * Financial product diversity score
# * Digital finance access indicator
# * County-level exclusion rate
# 6. __Data Preprocessing__
#
# * Encode categorical variables
# * Scale numeric variables if necessary
# * Handle class imbalance
# * Split data into training and testing sets
# 7. __Baseline Modeling__
#
# Train Logistic Regression model as the baseline classifier.
#
# 8. __Advanced Modeling__
#
# Train and compare:
# * Decision Tree
# * Random Forest
# * Gradient Boosting
# * XGBoost
# 9. __Model Evaluation__
#
# Evaluate using:
# * Accuracy
# * Precision
# * Recall
# * F1-score
# * ROC-AUC
# * Confusion Matrix
# Special focus:
# * Recall for identifying financially excluded individuals.
# 10. __Model Explainability__
#
# Use SHAP to:
# * Identify important predictors
# * Explain global model behavior
# * Explain individual predictions
# 11. __Risk Tier Creation__
#
# Convert prediction probabilities into:
# * Low Risk
# * Medium Risk
# * High Risk
# 12. __Deployment__
#
# Deploy final pipeline using Flask application.
# ### __Modeling Challenges__
# 1. __Target Leakage__
#
# Some variables used to define financial exclusion may accidentally leak information into the model, causing unrealistic performance.
# Example:
# * Using “has bank account” directly when defining exclusion status.
# 2. __Class Imbalance__
#
# Financially excluded individuals may represent a smaller portion of the dataset, causing the model to favor the majority class.
# Possible solutions:
# * SMOTE
# * Class weighting
# * Threshold tuning
# 3. __High Cardinality Categorical Variables__
#
# Variables like county may create many categories, increasing model complexity.
#
# 4. __Missing Data__
#
# Survey datasets often contain:
# * Missing responses
# * Refused answers
# * Unknown categories
# These require careful handling.
#
# 5. __Overfitting__
#
# Advanced ensemble models like Gradient Boosting may memorize training data instead of generalizing well.
# Solutions:
# * Cross-validation
# * Hyperparameter tuning
# * Early stopping
# 6. __Interpretability Challenges__
#
# More powerful models are usually harder to explain compared to Logistic Regression.
#
# This is why SHAP explainability will be important.
#
# 7. __Computational Complexity__
#
# Gradient Boosting and XGBoost may require:
# * Longer training time
# * Hyperparameter optimization
# 8. __Bias and Fairness__
#
# The model may unintentionally learn socioeconomic or geographic biases present in the data.
# Fair evaluation across:
# * Gender
# * Counties
# * Rural/urban groups
# will be important.
# 9. __Generalization to Future Trends__
#
# Financial behavior changes over time. Patterns from 2021 may not perfectly represent 2024 conditions. This makes comparison with 2024 FinAccess trends important.

# %% [markdown]
# ### __Identifying Feature Columns__
# Feature columns are the input variables used by the machine learning model to make predictions.
# In this project, the features will include demographic, geographic, and financial behavior variables that may influence financial exclusion risk.
# Possible feature columns include:
# * County
# * Age
# * Gender
# * Education level
# * Employment status
# * Rural/urban location
# * Mobile phone ownership
# * National ID ownership
# * Mobile money usage
# * Bank account usage
# * SACCO usage
# * Insurance usage
# * Pension access
# * Savings behavior
# * Borrowing behavior
# * Financial literacy indicators
#
# These variables help the model learn patterns associated with financial exclusion.

# %% [markdown]
# ### __Separating X and y__
# In machine learning, datasets are usually separated into:
# * X (Features/Input Variables)
# * y (Target Variable/Output)
#
# X — Feature Matrix
# X contains all predictor variables used for training the model.
#
# * X = df.drop("financial_excluded", axis=1)
#
# This removes the target column and keeps only the features.
# * y — Target Variable
#
# y contains the variable the model is trying to predict.
#
# * y = df["financial_excluded"]
#
# Where:
# 1 = Financially Excluded
# 0 = Financially Included
#
# The model learns the relationship between X and y during training.

# %% [markdown]
# ### __Train/Test Split__
# A train/test split divides the dataset into two parts:
# ##### Training Set
# Used to train the machine learning model.
#
# The model learns patterns from this data.
# ##### Testing Set
# Used to evaluate how well the model performs on unseen data.
#
# This helps measure whether the model can generalize beyond the training data.

# %% [markdown]
# ## __Stratification__
# Stratification ensures that both the training set and testing set maintain the same proportion of target classes.
# In this project:
#
# * Financially included individuals may be more common
# * Financially excluded individuals may be fewer
# This creates a class imbalance problem.
# ##### __Why Stratification Matters__
# Without stratification:
# * One dataset may contain too many included individuals
# * Another may contain too few excluded individuals
# This can produce unreliable evaluation results.
#
# Stratification preserves the class distribution in both sets.
